# %% [markdown]
# # 영화 리뷰 워드 임베딩 (Word2Vec, FastText)
# - gensim 라이브러리 사용 : pip install gensim
#     - Word2Vec : models.Word2Vec
#     - FastText : models.FastText

# %% [markdown]
# ## 1. 데이터 준비
# * 토큰화가 잘 되어 있는 filtered 데이터 사용

# %%
import pandas as pd
data_filename = './data/Korean_movie_reviews_2016_filtered.csv'
data_df = pd.read_csv(data_filename)
data_df.head()
# Out:
#                                               review  rate
# 0                           아니 딴 그렇 비 비탄 총 대체 왜 들 온겨     7
# 1      진심 쓰레기 영화 만들 무서 알 쫄아 틀었 이건 뭐 웃 거리 없는 쓰레기 영화 임     1
# 2  역대 좀비 영화 가장 최고다 원작 만화 읽어 보려 영화 보고 결정 하려 감독 간츠 ...    10
# 3                                     온종일 불편한 피 범벅 일     6
# 4    답답함 극치 움직일 잇으 좀 움직여 어지간히 좀비 봣으 얼 타고 때려 잡 때 되 않냐     1

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 788189 entries, 0 to 788188
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   review  785448 non-null  object
#  1   rate    788189 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 12.0+ MB

# %%
data_df.dropna(inplace=True)
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785448 entries, 0 to 788188
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   review  785448 non-null  object
#  1   rate    785448 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 18.0+ MB

# %%
# review만 모아서 review별 토큰 리스트로 변환
review_list = [review.split() for review in list(data_df.review)]
print(review_list[:2])

# review_list = []
# for review in list(data_df.review):
#     review_list.append(review.split())
# Out:
# [['아니', '딴', '그렇', '비', '비탄', '총', '대체', '왜', '들', '온겨'], ['진심', '쓰레기', '영화', '만들', '무서', '알', '쫄아', '틀었', '이건', '뭐', '웃', '거리', '없는', '쓰레기', '영화', '임']]

# %% [markdown]
# ## 1. Word2Vec 활용 영화 리뷰 워드 임베딩
# * https://radimrehurek.com/gensim/models/word2vec.html

# %% [markdown]
# ### Skipgram, negative=10 인 경우

# %%
# Word2Vec 모델 생성 및 학습 : window=3, min_count=3
from gensim.models import Word2Vec

model = Word2Vec(review_list, vector_size=100, sg=1, negative=10, window=3, min_count=5)

# %%
# 단어의 임베딩 벡터 확인
model.wv['이정재']
# Out:
# array([-0.04977152,  0.13994065, -0.08556359, -0.23207852, -0.43213388,
#        -0.25371176,  0.27554318, -0.02559499,  0.804486  , -0.15701887,
#        -0.5673242 , -0.46482053,  0.14749222,  0.2965173 ,  0.1291392 ,
#        -0.01093827,  0.05246805, -0.11855821,  0.17146549,  0.11125589,
#        -0.0718518 ,  0.03889091,  0.37434518, -0.13062398, -0.17475617,
#        -0.15423298, -0.10434791, -0.34806573, -0.16085522,  0.27177185,
#         0.42604038, -0.11335007, -0.22572011,  0.08497686, -0.01967368,
#        -0.616898  , -0.402567  , -0.41331255, -0.33328795,  0.10278249,
#        -0.74875563,  0.12314115, -0.2244742 , -0.5030652 , -0.28511158,
#        -0.09858644, -0.3376579 ,  0.01617431,  0.12572157,  0.27688098,
#         0.41120282, -0.48993668, -0.02607713, -0.2963185 ,  0.44792292,
#        -0.0848417 ,  0.03687896,  0.03308985, -0.09837785,  0.27424723,
#        -0.42138618,  0.07601947,  0.40363067, -0.3322658 , -0.6174557 ,
#        -0.06777304, -0.13963221,  0.04367938,  0.25074562, -0.5430095 ,
#         0.48726612,  0.3406653 ,  0.2945561 ,  0.37084976,  0.10511532,
#        -0.21630675,  0.16278543, -0.37338027, -0.52842945, -0.09625449,
#         0.02457941,  0.38534454, -0.38644344, -0.02109611, -0.19742784,
#        -0.07335086, -0.28520676, -0.2904481 ,  0.2832085 ,  0.10824445,
#         0.52968806,  0.53000355,  0.7362851 , -0.12305825,  0.39131808,
#         0.15696657,  0.43027174,  0.13698941,  0.44731677,  0.7049126 ],
#       dtype=float32)

# %%
# 단어의 임베딩 벡터 차원 확인
len(model.wv['이정재'])
# Out:
# 100

# %%
# 두 단어 간 유사도 확인
model.wv.similarity('이정재', '정우성')
# Out:
# np.float32(0.7443975)

# %%
# 특정 단어와 유사한 단어 추출
model.wv.most_similar('이정재', topn=20)
# Out:
# [('이범수', 0.8410192728042603),
#  ('송강호', 0.7996768951416016),
#  ('공유', 0.796018123626709),
#  ('김범수', 0.7906213402748108),
#  ('조재현', 0.755742609500885),
#  ('김윤석', 0.7531577348709106),
#  ('이성민', 0.7461482286453247),
#  ('정우성', 0.7443975210189819),
#  ('이병헌', 0.7218204140663147),
#  ('박해일', 0.720367431640625),
#  ('곽도원', 0.7200930714607239),
#  ('주지훈', 0.7127578258514404),
#  ('요한', 0.7111959457397461),
#  ('박철민', 0.7100128531455994),
#  ('김남길', 0.7001809477806091),
#  ('김성균', 0.6984980702400208),
#  ('오종혁', 0.6956399083137512),
#  ('최태준', 0.6940551996231079),
#  ('리암', 0.6927716135978699),
#  ('김성오', 0.6890100240707397)]

# %%
model.wv.most_similar('재밌', topn=50)
# Out:
# [('재미있', 0.8941774964332581),
#  ('재밌네', 0.8306862115859985),
#  ('재밌어', 0.8133973479270935),
#  ('잼남', 0.8122812509536743),
#  ('재밋음', 0.8109021782875061),
#  ('재밌었', 0.8054365515708923),
#  ('재밋엇음', 0.784522533416748),
#  ('재밋게봣', 0.7723993062973022),
#  ('재밌엇습니', 0.7646397352218628),
#  ('잼슴', 0.7609623670578003),
#  ('재밋어용', 0.7548702359199524),
#  ('재밋엇어용', 0.7543996572494507),
#  ('재밋었습니', 0.7542212009429932),
#  ('재밋구', 0.754182755947113),
#  ('재미있었', 0.7520524859428406),
#  ('쟈밋', 0.7513868808746338),
#  ('재밋어', 0.7483002543449402),
#  ('재밌슴', 0.745701789855957),
#  ('재밌더', 0.7441527843475342),
#  ('재밋습니', 0.7438651323318481),
#  ('재미있네', 0.7412566542625427),
#  ('재밌아', 0.740356981754303),
#  ('재밋네용', 0.7392838001251221),
#  ('재밋었어', 0.7380495667457581),
#  ('재밋엇', 0.7332942485809326),
#  ('재밋는듯', 0.7319116592407227),
#  ('재미있더', 0.7318347096443176),
#  ('재밋네', 0.7317154407501221),
#  ('재밋었음', 0.7312467694282532),
#  ('엇', 0.7297830581665039),
#  ('재밋습니당', 0.7297477722167969),
#  ('재밋게봣습니', 0.7290998697280884),
#  ('재밌드', 0.7281728982925415),
#  ('재밋당', 0.728093147277832),
#  ('재미있구', 0.7277305126190186),
#  ('재밋엇습니', 0.7271276712417603),
#  ('꿀잼임', 0.7266417145729065),
#  ('존잼임', 0.7255862951278687),
#  ('재밋습', 0.7224372029304504),
#  ('꾸르잼', 0.7210080027580261),
#  ('재밋엇어', 0.7208356261253357),
#  ('재밋게봣어', 0.719777524471283),
#  ('재밋게봄', 0.7188974618911743),
#  ('재밌고', 0.7162622213363647),
#  ('개꿀잼', 0.7119446992874146),
#  ('짱재밋어', 0.7116561532020569),
#  ('꿀잼', 0.7114502191543579),
#  ('존잼', 0.7113276720046997),
#  ('쟈밋어', 0.7109459042549133),
#  ('재밋었', 0.7102060317993164)]

# %%
model_sg_n10 = model

# %% [markdown]
# ### Skipgram, negative=5 인 경우

# %%
# 모델 생성

# %%
# 특어 단어와 유사한 단어 추출 : 이정재

# %%
# 특어 단어와 유사한 단어 추출 : 재밌

# %% [markdown]
# ### CBOW, negative=10 인 경우

# %%
model = Word2Vec(review_list, vector_size=100, sg=0, negative=10, window=3, min_count=5)

# %%
model.wv.most_similar('이정재', topn=20)
# Out:
# [('이범수', 0.7894725799560547),
#  ('공유', 0.7714797258377075),
#  ('김윤석', 0.7635565400123596),
#  ('조재현', 0.7403964400291443),
#  ('김범수', 0.7336829304695129),
#  ('이진욱', 0.7277397513389587),
#  ('박해일', 0.7082895040512085),
#  ('송강호', 0.7033631801605225),
#  ('주지훈', 0.7031623721122742),
#  ('이성민', 0.7002325654029846),
#  ('김남길', 0.6747239232063293),
#  ('차승원', 0.6706634163856506),
#  ('정우성', 0.6637006998062134),
#  ('민호', 0.6595103740692139),
#  ('하정우', 0.6524418592453003),
#  ('이병헌', 0.6522388458251953),
#  ('김명민', 0.6447588205337524),
#  ('곽도원', 0.6406233310699463),
#  ('류승범', 0.6404667496681213),
#  ('조정석', 0.6381457448005676)]

# %%
model.wv.most_similar('재밌', topn=50)
# Out:
# [('재미있', 0.904577374458313),
#  ('재밌네', 0.8119208812713623),
#  ('재밌어', 0.797929584980011),
#  ('재밋음', 0.78677898645401),
#  ('재밌었', 0.7847074270248413),
#  ('재밌는', 0.7221318483352661),
#  ('잼남', 0.7109394073486328),
#  ('재미있었', 0.7051357626914978),
#  ('재밋어', 0.6865072846412659),
#  ('재미있네', 0.6863694787025452),
#  ('재밌더', 0.6804366111755371),
#  ('재밋네', 0.6794679164886475),
#  ('재밋엇어', 0.6755865812301636),
#  ('재미있어', 0.664637565612793),
#  ('재밌던', 0.6616527438163757),
#  ('재밋', 0.6588318347930908),
#  ('재밋었어', 0.6442877650260925),
#  ('재밌고', 0.6400436758995056),
#  ('재밌다', 0.638820230960846),
#  ('꿀잼', 0.6379734873771667),
#  ('재밋었', 0.6291570663452148),
#  ('재미있는', 0.6262257695198059),
#  ('재미있던', 0.6255902647972107),
#  ('재밋엇', 0.6195635795593262),
#  ('재밌구', 0.6163502931594849),
#  ('재밋엇음', 0.6124737858772278),
#  ('잼', 0.606905460357666),
#  ('재밋었음', 0.6023034453392029),
#  ('재밋습니', 0.5835156440734863),
#  ('재밌게', 0.5833075046539307),
#  ('웃김', 0.5721863508224487),
#  ('재미있다', 0.5581219792366028),
#  ('재미있고', 0.5564887523651123),
#  ('개꿀잼', 0.5550765991210938),
#  ('존잼', 0.5429179072380066),
#  ('재밌으', 0.5312601327896118),
#  ('재밌겠', 0.5308207869529724),
#  ('재미있더', 0.5272330641746521),
#  ('재미있게', 0.5219689011573792),
#  ('괜찮', 0.5200669169425964),
#  ('재미나', 0.5104338526725769),
#  ('멋있', 0.507547914981842),
#  ('재미없', 0.49915340542793274),
#  ('무서웠', 0.49186447262763977),
#  ('웃겼', 0.4899228811264038),
#  ('졸잼', 0.486184686422348),
#  ('재밋어용', 0.48160481452941895),
#  ('재미있구', 0.4792881906032562),
#  ('재미있겠', 0.4784291982650757),
#  ('괜찬', 0.47587883472442627)]

# %%
model_cb_n10 = model

# %% [markdown]
# ### CBOW, negative=5 인 경우

# %% [markdown]
# ### OOV(Out of Vocabulary) 문제

# %%
# corpus에 없는 단어 확인 : 우주평화 
model = model_sg_n10
'우주평화' in model.wv.key_to_index
# Out:
# False

# %%
# corpus에 없는 단어의 임베딩 벡터 확인 
model.wv['우주평화']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 # corpus에 없는 단어의 임베딩 벡터 확인
# ----> 2 model.wv['우주평화']
#
# File c:\Users\user\anaconda3\envs\aiservice26\lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)
#     400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File c:\Users\user\anaconda3\envs\aiservice26\lib\site-packages\gensim\models\keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
#     423     """Get the key's vector, as a 1D numpy array.
#     424
#     425     Parameters
#    (...)
#     444
#     445     """
# --> 446     index = self.get_index(key)
#     447     if norm:
#     448         self.fill_norms()
#
# File c:\Users\user\anaconda3\envs\aiservice26\lib\site-packages\gensim\models\keyedvectors.py:420, in KeyedVectors.get_index(self, key, default)
#     418     return default
#     419 else:
# --> 420     raise KeyError(f"Key '{key}' not present")
#
# KeyError: "Key '우주평화' not present"

# %% [markdown]
# ## 2. FastText 활용 영화 리뷰 워드 임베딩
# * https://radimrehurek.com/gensim/models/fasttext.html

# %%
# FastText 모델 생성 및 학습
# window=3, min_count=3, min_n=2, max_n=2
from gensim.models import FastText
model = FastText(review_list, vector_size=100, sg=1, negative=10, window=3, min_count=3, min_n=2, max_n=2)

# %%
# 특정 단어와 유사한 단어 추출 : 이정재
model.wv.most_similar('이정재', topn=20)
# Out:
# [('이범수', 0.863810658454895),
#  ('정재영', 0.8375847935676575),
#  ('정재', 0.8304333090782166),
#  ('정재형', 0.8128597140312195),
#  ('김범수', 0.8063018918037415),
#  ('공유', 0.804658830165863),
#  ('임성민', 0.7990655303001404),
#  ('송강호', 0.789299488067627),
#  ('박해일', 0.7753555774688721),
#  ('김지민', 0.7744220495223999),
#  ('이성민', 0.7698089480400085),
#  ('톰슨', 0.765968382358551),
#  ('김성균', 0.7648169994354248),
#  ('김철민', 0.7623989582061768),
#  ('김성민', 0.76054847240448),
#  ('이진욱', 0.7589315176010132),
#  ('강호', 0.7553239464759827),
#  ('김윤아', 0.7552953362464905),
#  ('마동석', 0.7525989413261414),
#  ('이정현', 0.7509468197822571)]

# %%
# corpus에 없는 단어 확인 : 우주평화 
'우주평화' in model.wv.key_to_index
# Out:
# False

# %%
# corpus에 없는 단어의 임베딩 벡터 확인 
model.wv['우주평화']
# Out:
# array([ 0.23896429,  0.25109178,  0.20485029,  0.16798005, -0.01154498,
#        -0.13721971, -0.18858692,  0.83621025,  0.34104794,  0.40727362,
#        -0.10395794,  0.09189446,  0.12232091,  0.30942592, -0.15851183,
#        -0.28945178,  0.09517287, -0.2086474 ,  0.02482669,  0.10074421,
#         0.19177976,  0.16100061,  0.06309381, -0.01932592,  0.0109815 ,
#        -0.05356969, -0.64141244, -0.2548179 , -0.15149511, -0.18019268,
#         0.12024485, -0.3458901 ,  0.33648163, -0.34056178, -0.13261135,
#         0.27626616,  0.03424796,  0.02029523, -0.18327719, -0.12185627,
#        -0.18883447,  0.01034344, -0.23166604, -0.04126205, -0.22260411,
#         0.09179086, -0.07938954, -0.00242083, -0.20365703,  0.14458337,
#         0.18615553,  0.3815965 , -0.0720449 , -0.23900041, -0.23535411,
#         0.00804855,  0.19411048,  0.13993089, -0.08787031,  0.3583147 ,
#         0.11663027,  0.11539751, -0.41468757, -0.20222564, -0.36596277,
#        -0.23887148, -0.07709685, -0.21466129,  0.1436364 ,  0.03561605,
#        -0.14050099, -0.2058157 ,  0.38569218, -0.0721461 , -0.03405169,
#         0.27775884,  0.17963819, -0.3257012 , -0.14805512, -0.14421481,
#        -0.5547074 , -0.24913469,  0.19690818,  0.22761682,  0.16207126,
#         0.01560578, -0.4944659 ,  0.16560872, -0.01381167, -0.04342576,
#        -0.04961898,  0.35043436, -0.4016939 , -0.02201095, -0.03396112,
#         0.54204667, -0.4471354 , -0.15910138, -0.3518346 ,  0.14575818],
#       dtype=float32)

# %%
# corpus에 없는 단어와 유사한 단어추출 
model.wv.most_similar('우주평화', topn=20)
# Out:
# [('우주', 0.8236177563667297),
#  ('회색곰', 0.8087837100028992),
#  ('우주비행사', 0.8056885004043579),
#  ('평화', 0.8024688363075256),
#  ('우주인', 0.7991050481796265),
#  ('우장', 0.7930383682250977),
#  ('장래희망', 0.7860912680625916),
#  ('우방', 0.7860497236251831),
#  ('우주선', 0.7842202186584473),
#  ('아우슈비츠', 0.7804217338562012),
#  ('무궁화', 0.7799226641654968),
#  ('우주여행', 0.7798065543174744),
#  ('투명인간', 0.7778528332710266),
#  ('지구인', 0.7754669785499573),
#  ('우화', 0.7732598185539246),
#  ('켤', 0.7730500102043152),
#  ('아비규환', 0.7703302502632141),
#  ('대영제국', 0.7629257440567017),
#  ('볐', 0.7624824047088623),
#  ('산전수전', 0.7617990970611572)]
